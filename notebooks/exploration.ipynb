# %% [markdown]
# # Sector Pulse Exploration
# Use this notebook for ad-hoc validation and live-data findings. The committed sample database is synthetic.

# %%
import duckdb
conn = duckdb.connect('../data/sample.duckdb', read_only=True)
conn.execute('SELECT ticker, metric, date, z_score, description FROM fact_anomaly WHERE flagged ORDER BY abs(z_score) DESC LIMIT 20').df()
